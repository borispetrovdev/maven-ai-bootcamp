# %% [markdown]
# ### Import Dependencies

# %%
from langsmith import Client

# %% [markdown]
# ### Attach Feedback to a specific trace in LangSmith

# %%
client = Client()

# %%
# https://smith.langchain.com/o/698bb56f-cd76-4ac4-bf78-0dec190b462d/projects/p/8b890607-d20c-4d58-99e4-7ac9c290d2df?timeModel=%7B%22duration%22%3A%227d%22%7D&peek_start=2026-07-21T00%3A07%3A32.622832Z&peek_project=8b890607-d20c-4d58-99e4-7ac9c290d2df&runview=threads&searchModel=%7B%7D&peekedConversationId=4b2abaac-24e7-4338-9c17-8a98347c9c67&minStartTime=2026-07-21T00%3A07%3A32.622832Z&maxStartTime=2026-07-21T00%3A08%3A32.622Z&start_time=2026-07-21T00%3A07%3A32.622832Z&run_id=019f81ff-cc0e-7b92-86d8-94ebbddacbfe&conversationTab=trace&trace_id=019f81ff-cc0e-7b92-86d8-94ebbddacbfe
RUN_ID = "019f81ff-cc0e-7b92-86d8-94ebbddacbfe"

# %%
client.create_feedback(
  run_id=RUN_ID,
  key="feedback",
  score=0,
  feedback_source_type="api",
)

# %%
client.create_feedback(
    run_id=RUN_ID,
    key="comment",
    value="This is a long form free text feedback, left by Boris",
    feedback_source_type="api",
)

# %%
client.create_feedback(
    run_id=RUN_ID,
    key="comment_with_score",
    value="This is a long form free text feedback, left by Boris",
    score=1,
    feedback_source_type="api",
)
